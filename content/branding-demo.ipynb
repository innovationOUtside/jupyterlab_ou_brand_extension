# %% [markdown]
# # Custom Branding Demo
#
# The JuyterLab abnd RetroLab (notebook v.7) environments should have custom branded logos.
#
# ![image.png](attachment:b8779224-33c0-4e35-bbae-6293d9364c20.png)
